# %%
import mod1

print(mod1.add(3, 4))
print(mod1.sub(4, 3))
# Out:
# 7
# 1

# %%
from mod1 import add, sub

print(add(7, 10))
print(sub(10, 3))
# Out:
# 17
# 7

# %%
from mod1 import *

print(add(7, 10))
print(sub(10, 7))
# Out:
# 17
# 3

# %%
from mod1 import add

add(3, 4)
# Out:
# 7
