# %%
# 튜플은 어떻게 만들까
t1 = ()
t2 = (1, )
t3 = (1, 2, 3)
t4 = 1, 2, 3 # 괄호 생략 가능
t5 = ("a", "b", ("ab", "cd"))

a = list()
b = tuple()

# a = 1, # 튜플
# b = 1  # 변수
# Out:
# []

# %%
t1 = (1, 2, "a", "b")

# 튜플 요소값을 삭제하려 할때 -> 지울 수 없음
del t1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 t1 = (1, 2, "a", "b")
# ----> 3 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1 = (1, 2, "a", "b")

# 튜플 요소값을 변경하려 할때
t1[1] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 t1 = (1, 2, "a", "b")
#       3 # 튜플 요소값을 변경하려 할때
# ----> 4 t1[1] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
# 인덱싱하기
t1 = (1, 2, "a", "b")
t1[2]
# Out:
# 'a'

# %%
# 슬라이싱하기
t1 = (1, 2, "a", "b")
t1[2:]
# Out:
# ('a', 'b')

# %%
# 튜플 더하기
t1 = (1, 2, "a", "b")
t2 = (3, 4)
t1 + t2
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
# 튜플 곱하기
t2 = (3, 4)
t2 * 3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
# 튜플의 길이 구하기
t1 = (1, 2, "a", "b")
len(t1)
# Out:
# 4
