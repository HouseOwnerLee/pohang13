# %%
# 리스트는 어떻게 만들까
odd = [1, 3, 5, 7, 9]

a = []
b = [1, 2, 3]
c = ["Life", "is", "short"]
d = [1, 2, ["Life", "is"]]
# Out:
# []

# %%
# 리스트의 인덱싱
a = [1, 2, 3]
a[0] + a[2]
# Out:
# 4

# %%
a = [1, 2, 3, ["a", "b", "c"]]
print(a[3][1])
print(a[-1][-1])
# Out:
# b
# c

# %%
a = [1, 2, ["a", "b", ["Life", "is"]]]

print(a[-1][-1][0])
# Out:
# Life

# %%
# 리스트의 슬라이싱
a = [1, 2, 3, 4, 5]
a[0:4]
# Out:
# [1, 2, 3, 4]

# %%
a = [1, 2, 3, ["a", "b", "c"], 4, 5]
print(a[3][0:2])
# Out:
# ['a', 'b']

# %%
# 리스트의 더하기
a = [1, 2, 3]
b = [4, 5, 6]

a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 리스트의 곱하기
a = [1, 2, 3]
a * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트의 길이 구하기
a = [1, 2, 3, 4, 5]
len(a)
# Out:
# 5

# %%
# 리스트의 수정과 삭제
a = [1, 2, 3]
a[2] = 4
a
# Out:
# [1, 2, 4]

# %%
# del로 리스트 요소 삭제
a = [1, 2, 3]
del a[1]
print(a)
# Out:
# [1, 3]

# %%
a = [1, 2, 3, 4, 5]
del a[2:]
print(a)
# Out:
# [1, 2]

# %%
# 리스트 관련 함수
## 리스트 요소 추가하기 - append()

a = [1, 2, 3]
# b = [4]
# a + b

a.append(4)
a
# Out:
# [1, 2, 3, 4]

# %%
# 리스트 정렬
a = [1, 4, 3, 2]
a.sort()
a.sort(reverse = True)
a
# Out:
# [4, 3, 2, 1]

# %%
a = ["a", "c", "b"]
a.reverse()
a
# Out:
# ['b', 'c', 'a']

# %%
# 인덱스 반환 - index
a = [1, 2, 3]
a.index(1)
a.index(2)
a.index(3)
# Out:
# 2

# %%
# 리스트에 요소 삽입
a = [1, 2, 3]
a.insert(0,4)
a
# Out:
# [4, 1, 2, 3]

# %%
a.insert(3,5)
a
# Out:
# [4, 1, 2, 5, 3]

# %%
# 리스트 요소 제거
a = [1, 2, 3, 1, 2, 3]
a.remove(3)
a
# Out:
# [1, 2, 1, 2, 3]

# %%
# 리스트 요소 꺼내기 - pop
a = [1,2,3]
a.pop(1)
a
# Out:
# [1, 3]

# %%
# 리스트에 포함된 요소 x의 개수 세기 - count
a = [1, 2, 3, 1]
a.count(1)
# Out:
# 2

# %%
# 리스트의 확장 - extend
a = [1, 2, 3]
a.extend([4,5])
a
# Out:
# [1, 2, 3, 4, 5]
